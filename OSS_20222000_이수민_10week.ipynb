# %%
#예제 1
a = [1,2,3]
b = a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
#예제 2
class Gizmo:
  def __init__(self):
    print('Gizmo id : %d' % id(self))

x = Gizmo()
y = Gizmo()
dir()
# Out:
# Gizmo id : 134577232121200
# Gizmo id : 134577232121680
# ['Gizmo',
#  'In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'b',
#  'exit',
#  'get_ipython',
#  'quit',
#  'x',
#  'y']

# %%
#예제 3
charles = {'name':"Charles L.Dogson",'born':1832}
lewis = charles
print(lewis is charles)
print(id(charles), id(lewis))
lewis['balance'] = 950
print(charles)
# Out:
# True
# 134576704030400 134576704030400
# {'name': 'Charles L.Dogson', 'born': 1832, 'balance': 950}

# %%
#예제 4
alex = {'name': 'Charles L.Dogson', 'born': 1832, 'balance': 950}
print(alex==charles)
print(alex is charles)
# Out:
# True
# False

# %%
#예제 5
t1 = (1,2,[30,40])
t2 = (1,2,[30,40])

print(t1==t2, t1 is t2)
print(id(t1[-1]))
t1[-1].append(99)
print(t1,id(t1[-1]))
print(t1==t2)
# Out:
# True False
# 134576704038528
# (1, 2, [30, 40, 99]) 134576704038528
# False

# %%
#예제 6
l1 = [3,[66,55,44],(7,8,9)]
l2 = list(l1)
l1.append(100)
l1[1].remove(55)
print('l1:', l1)
print('l2:',l2)
l2[1]+=[33,22]
l2[2]+=(10,11)
print('l1:', l1)
print('l2:',l2)
# Out:
# l1: [3, [66, 44], (7, 8, 9), 100]
# l2: [3, [66, 44], (7, 8, 9)]
# l1: [3, [66, 44, 33, 22], (7, 8, 9), 100]
# l2: [3, [66, 44, 33, 22], (7, 8, 9, 10, 11)]

# %%
#예제 7
class Bus:
  def __init__(self,passengers=None):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = list(passengers)

  def pick(self,name):
    self.passengers.append(name)
  def drop(self,name):
    self.passengers.remove(name)

# %%
#예제 8
import copy
bus1 = Bus(['Alice','Bill','Claire','David'])
bus2 = copy.copy(bus1)
bus3 = copy.deepcopy(bus1)
print(id(bus1),id(bus2),id(bus3))
# Out:
# 134576712840208 134576712838864 134576712837664

# %%
bus1.drop('Bill')
bus1.passengers,bus2.passengers,bus3.passengers
print(id(bus1.passengers),id(bus2.passengers),id(bus3.passengers))
# Out:
# 134576706360000 134576706360000 134576705197440

# %%
#예제 9
a = [10,20]
b = [a,30]
a.append(b)
print(a)
c = copy.deepcopy(a)
print(c)
# Out:
# [10, 20, [[...], 30]]
# [10, 20, [[...], 30]]

# %%
#예제 10
def f(a,b):
  a+=b
  return a

x = 1
y = 2
f(x,y), (x,y)
# Out:
# (3, (1, 2))

# %%
a = [1,2]
b = [3,4]
f(a,b),(a,b)
# Out:
# ([1, 2, 3, 4], ([1, 2, 3, 4], [3, 4]))

# %%
t = (10,20)
u = (30,40)
f(t,u),(t,u)
# Out:
# ((10, 20, 30, 40), ((10, 20), (30, 40)))

# %%
#예제 11
class HauntedBus:
  def __init__(self,passengers=[]):
    self.passengers = passengers
  def pick(self,name):
    self.passengers.append(name)
  def drop(self,name):
    self.passengers.remove(name)

# %%
#예제 12
bus1 = HauntedBus(['Alice','Bill'])
bus1.passengers
# Out:
# ['Alice', 'Bill']

# %%
bus1.pick('charlie')
bus1.drop('Alice')
bus1.passengers
# Out:
# ['Bill', 'charlie']

# %%
bus2 = HauntedBus()
bus2.pick('Carrie')
bus2.passengers
# Out:
# ['Carrie']

# %%
bus3 = HauntedBus()
bus3.passengers
# Out:
# ['Carrie']

# %%
bus3.pick('Dave')
bus2.passengers
# Out:
# ['Carrie', 'Dave']

# %%
bus2.passengers is bus3.passengers
# Out:
# True

# %%
bus1.passengers
# Out:
# ['Bill', 'charlie']

# %%
HauntedBus.__init__.__defaults__
# Out:
# (['Carrie', 'Dave'],)

# %%
HauntedBus.__init__.__defaults__[0] is bus2.passengers
# Out:
# True

# %%
#예제 13
class TwilightBus:
  def __init__(self,passengers=[None]):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = passengers
  def pick(self,name):
    self.passengers.append(name)
  def drop(self,name):
    self.passengers.remove(name)

# %%
#예제 14
basketball_team = ['Sue', 'Tina','Maya','Diana','Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Maya', 'Diana']

# %%
#예제 15
class TwilightBus:
  def __init__(self,passengers=[None]):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = list(passengers)
  def pick(self,name):
    self.passengers.append(name)
  def drop(self,name):
    self.passengers.remove(name)

# %%
#예제 16
basketball_team = ['Sue', 'Tina','Maya','Diana','Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']

# %%
#예제 17
import weakref
s1 = {1,2,3}
s2 = s1
def bye():
  print('Gone with the wind...')
ender = weakref.finalize(s1,bye)
ender.alive
# Out:
# True

# %%
del s1
ender.alive
# Out:
# True

# %%
s2 = 'spam'
# Out:
# Gone with the wind...

# %%
ender.alive
# Out:
# False
